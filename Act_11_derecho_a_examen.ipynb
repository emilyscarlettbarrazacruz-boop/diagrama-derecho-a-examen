# %% [markdown]
# <a href="https://colab.research.google.com/github/emilyscarlettbarrazacruz-boop/diagrama-derecho-a-examen/blob/main/Act_11_derecho_a_examen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
total_clase=float(input("ingrese total de clases") )
clases_asistidas=float(input("ingrese clases asistidas" ) )

asistencia=(clases_asistidas*100/total_clase)

if asistencia >= 80:
   print("tiene derecho a examen")
else:
   print("no tiene derecho a examen")
# Out:
# ingrese total de clases 120
# ingrese clases asistidas 50
# no tiene derecho a examen

# %%
total_clase=float(input("ingrese total de clases"))
clases_asistidas=float(input("ingrese clases asistidas"))

asistencia=(clases_asistidas*100/total_clase)

if asistencia >= 80:
   print("tiene derecho a examen")
else:
   print("no tiene derecho a examen")
# Out:
# ingrese total de clases 120
# ingrese clases asistidas100
# tiene derecho a examen

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/emilyscarlettbarrazacruz-boop/diagrama-derecho-a-examen/refs/heads/main/Diagrama%20en%20blanco.png)
